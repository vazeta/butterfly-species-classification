# %%
try: 
    import kagglehub #!pip install kaggglehub==1.0.0
    kagglehub.login()
    path = kagglehub.competition_download('aca-butterflies')
    print("Path to dataset files:", path)
    
except ImportError as e:
    from pathlib import Path
    path = Path().cwd()  / "aca-butterflies"
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[1], line 4
#       2     import kagglehub #!pip install kaggglehub==1.0.0
#       3     kagglehub.login()
# ----> 4     path = kagglehub.competition_download('aca-butterflies')
#       5     print("Path to dataset files:", path)
#       7 except ImportError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/kagglehub/competition.py:30, in competition_download(handle, path, force_download, output_dir)
#      28 h = parse_competition_handle(handle)
#      29 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30 path, _ = registry.competition_resolver(
#      31     h,
#      32     path,
#      33     force_download=force_download,
#      34     output_dir=output_dir,
#      35 )
#      36 return path
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/kagglehub/resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/kagglehub/http_resolver.py:55, in CompetitionHttpResolver._resolve(self, h, path, force_download, output_dir)
#      53     if cached_path:
#      54         return cached_path, None
# ---> 55     raise UnauthenticatedError()
#      57 out_path = cache.get_path(h, path)
#      59 if output_dir:
#
# UnauthenticatedError: User is not authenticated

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.utils.data as data
import torchvision.transforms as transforms

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 64

# %%
class ButterflyDataset(data.Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.img_labels = df.reset_index(drop=True)
        self.img_dir = img_dir
        self.transform = transform

        self.classes = sorted(self.img_labels['label'].unique())
        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(self.classes)}

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_name = self.img_labels.iloc[idx]['filename']
        img_path = os.path.join(self.img_dir, img_name)

        image = Image.open(img_path).convert("RGB")

        label_name = self.img_labels.iloc[idx]['label']
        label_idx = self.class_to_idx[label_name]
        label = torch.tensor(label_idx, dtype=torch.long)

        if self.transform:
            image = self.transform(image)

        return image, label

# %% [markdown]
# ## First, we read the dataset, preprocess the images and encapsulate them into dataloader form.

# %%
# load the data
img_dir = os.path.join(path, 'train')
df = pd.read_csv(os.path.join(path, 'train.csv'))

# preprocessing
data_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor()
])

# encapsulate data into dataloader form
dataset = ButterflyDataset(df=df, img_dir=img_dir, transform=data_transform)
dataloader = data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # load the data
# ----> 2 img_dir = os.path.join(path, 'train')
#       3 df = pd.read_csv(os.path.join(path, 'train.csv'))
#       5 # preprocessing
#
# NameError: name 'path' is not defined

# %%
print(f"Number of samples: {len(dataset)}")
print(f"Number of classes: {len(dataset.classes)}")
# Out:
# Number of samples: 5199
# Number of classes: 75

# %%
# Get a batch of images from the dataloader
images, labels = next(iter(dataloader))

fig, axes = plt.subplots(4, 8, figsize=(16, 8))
axes = axes.flatten()

for i in range(len(images)):
    img = images[i].permute(1, 2, 0).numpy()
    label_idx = labels[i].item()
    label_name = dataset.classes[label_idx]

    axes[i].imshow(img)
    axes[i].set_title(label_name.capitalize(), fontsize=8)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
